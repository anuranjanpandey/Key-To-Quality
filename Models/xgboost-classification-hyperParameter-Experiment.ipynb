# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from math import sqrt
import xgboost as xgb
import time
from sklearn.metrics import classification_report, accuracy_score, mean_squared_error
from tabulate import tabulate 


fractional_to_integer_mapping = {
    0.5: 0,
    1.0: 1,
    1.5: 2,
    2.0: 3,
    2.5: 4,
    3.0: 5,
    3.5: 6,
    4.0: 7,
    4.5: 8,
    5.0: 9,
    5.5: 10,
    6.0: 11
}


train_data = pd.read_csv('/kaggle/input/finaldf/final_df.csv')


# Apply the mapping to the 'score' column
train_data['score'] = train_data['score'].map(fractional_to_integer_mapping) # no need of this
train_data.head()
# Out:
#          id  num_backspaces  duration_backspaces  num_cut/copy/paste  \
# 0  001519c8           417.0              34130.0                 417
# 1  0022f953           260.0              23550.0                 261
# 2  0042269b           439.0              32905.0                 439
# 3  0059420b           152.0              18411.0                 152
# 4  0075873a           517.0              40199.0                 517
#
#    discarded_text  D/I Ratio  Proportion_of_Deletions  no_distant_revision  \
# 0             489   0.243284                 0.164512                 2517
# 1             266   0.138287                 0.097316                 2354
# 2             935   0.266003                 0.221984                 4037
# 3             163   0.134202                 0.092302                 1473
# 4             517   0.266220                 0.164806                 2490
#
#    no_immediate_revision  major_edits_count  ...  \
# 0                   40.0                 93  ...
# 1                  100.0                 45  ...
# 2                   99.0                173  ...
# 3                   83.0                 19  ...
# 4                   41.0                124  ...
#
#    Total_Pause_Time_within_word  Mean_Pause_Time_within_word  \
# 0                        685007                  1918.787115
# 1                       1087710                  2781.867008
# 2                        843679                  1528.403986
# 3                        745392                  3067.456790
# 4                       1039641                  3208.768519
#
#    SD_Pause_Time_within_word  Total_Pause_Time_Before_Sentences  \
# 0                7273.768138                               3643
# 1               16954.357992                              69412
# 2                9793.226830                              87089
# 3               13400.325753                            1466851
# 4               11181.242502                             142133
#
#    Mean_Pause_Time_Before_Sentences  SD_Pause_Time_Before_Sentences  \
# 0                        173.476190                      416.665168
# 1                       4627.466667                     8278.455203
# 2                       4147.095238                    15826.690943
# 3                     112834.692308                   365509.369147
# 4                       6179.695652                    13762.720184
#
#    Total_Pause_Time_in_sentences  Mean_Pause_Time_in_sentences  \
# 0                        1181819                  56277.095238
# 1                         581673                  38778.200000
# 2                        1259632                  59982.476190
# 3                        1032626                  79432.769231
# 4                        1073221                  46661.782609
#
#    SD_Pause_Time_in_sentences  score
# 0                43455.913672      6
# 1                32758.883810      6
# 2                58697.726407     11
# 3                48355.056728      3
# 4                73950.739406      7
#
# [5 rows x 51 columns]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    train_data.drop(['score', 'id'], axis=1),
    train_data['score'],
    test_size=0.2,
    random_state=42
)
X_train.head()
y_train.head()
# Out:
# 1610    8
# 1525    9
# 2366    4
# 859     5
# 497     3
# Name: score, dtype: int64

# %%
# Try out some values to get the best hyper parameters
def train_and_evaluate(X_train, y_train, X_valid, y_valid, max_depth, learning_rate, n_estimators):

    xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=12, seed=42, max_depth=max_depth, learning_rate=learning_rate, n_estimators=n_estimators)
    xgb_model.fit(X_train, y_train)
    y_pred = xgb_model.predict(X_valid)
    
    # Inverse mapping dictionary
    integer_to_fractional_mapping = {v: k for k, v in fractional_to_integer_mapping.items()}

    # Convert predicted values back to fractional scores
    y_pred_original = [integer_to_fractional_mapping[int(prediction)] for prediction in y_pred]

    # Convert true values back to fractional scores (if needed)
    y_valid_original = [integer_to_fractional_mapping[int(true_value)] for true_value in y_valid]
    
    # Evaluate the model
    rmse = np.sqrt(mean_squared_error(y_valid_original, y_pred_original))
    return rmse

# Initialize variables to keep track of the best hyperparameters and lowest RMSE
best_hyperparams = {'max_depth': 0, 'learning_rate': 0, 'n_estimators': 0}
lowest_rmse = float('inf')

for depth in range(6, 17):
    for rate in np.arange(0.01, 0.41, 0.04):
        for n_estimators in range(50, 151, 10):
            rmse = train_and_evaluate(X_train, y_train, X_valid, y_valid, max_depth=depth, learning_rate=rate, n_estimators=n_estimators)
            
            # Update best hyperparameters if the current RMSE is lower
            if rmse < lowest_rmse:
                lowest_rmse = rmse
                best_hyperparams['max_depth'] = depth
                best_hyperparams['learning_rate'] = rate
                best_hyperparams['n_estimators'] = n_estimators
            
            print(f"Max Depth: {depth}, Learning Rate: {rate:.2f}, n_estimators: {n_estimators}, RMSE: {rmse:.4f}, Lowest RMSE: {lowest_rmse:.4f}")
# Out:
# Max Depth: 6, Learning Rate: 0.01, n_estimators: 50, RMSE: 0.8134, Lowest RMSE: 0.8134
# Max Depth: 6, Learning Rate: 0.01, n_estimators: 60, RMSE: 0.7968, Lowest RMSE: 0.7968
# Max Depth: 6, Learning Rate: 0.01, n_estimators: 70, RMSE: 0.7968, Lowest RMSE: 0.7968
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 28
#      26 for rate in np.arange(0.01, 0.41, 0.04):
#      27     for n_estimators in range(50, 151, 10):
# ---> 28         rmse = train_and_evaluate(X_train, y_train, X_valid, y_valid, max_depth=depth, learning_rate=rate, n_estimators=n_estimators)
#      30         # Update best hyperparameters if the current RMSE is lower
#      31         if rmse < lowest_rmse:
#
# Cell In[6], line 5, in train_and_evaluate(X_train, y_train, X_valid, y_valid, max_depth, learning_rate, n_estimators)
#       2 def train_and_evaluate(X_train, y_train, X_valid, y_valid, max_depth, learning_rate, n_estimators):
#       4     xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=12, seed=42, max_depth=max_depth, learning_rate=learning_rate, n_estimators=n_estimators)
# ----> 5     xgb_model.fit(X_train, y_train)
#       6     y_pred = xgb_model.predict(X_valid)
#       8     # Inverse mapping dictionary
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:1515, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1487 (
#    1488     model,
#    1489     metric,
#    (...)
#    1494     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1495 )
#    1496 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1497     missing=self.missing,
#    1498     X=X,
#    (...)
#    1512     feature_types=self.feature_types,
#    1513 )
# -> 1515 self._Booster = train(
#    1516     params,
#    1517     train_dmatrix,
#    1518     self.get_num_boosting_rounds(),
#    1519     evals=evals,
#    1520     early_stopping_rounds=early_stopping_rounds,
#    1521     evals_result=evals_result,
#    1522     obj=obj,
#    1523     custom_metric=metric,
#    1524     verbose_eval=verbose,
#    1525     xgb_model=model,
#    1526     callbacks=callbacks,
#    1527 )
#    1529 if not callable(self.objective):
#    1530     self.objective = params["objective"]
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
#    2049     _check_call(
# -> 2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
